# %% [markdown]
# # Web Scraping with Beautiful Soup
#
# ![](https://sixfeetup.com/blog/an-introduction-to-beautifulsoup/@@images/1cc2fc44-5ac8-4378-bef2-95048d5bc5ad.png)
#
# Frequently we don't have access to any/enough data to perform accurate analysis, this is a common issue to a new/nich project. In those cases, we might need to find a way to collect data on our own.
#
# __A Web Scraper__ is a program that extract data from a website. __BeautifulSoup__ is a Python library that provides many functions to pull data out of HTML and XML files.
#
# For more information, please read the documentation of Beautiful Soup: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ### Problem Statement
# - Build a Web Scraper to collect data about articles on [https://vnexpress.net/](https://vnexpress.net/).
# - Required information:
#   - Title
#   - Description
#   - Link to the Article
#   - Link to Thumbnail Image

# %% [markdown]
# ## Send GET Request to the Website
#
# The first step is to request a HTML text file of vnexpress. We can archieve that by sending a [GET request](https://www.w3schools.com/tags/ref_httpmethods.asp) to [https://vnexpress.net/]( https://vnexpress.net/) using the Python library `requests`.

# %%
import requests
base_url ='https://tiki.vn'
r = requests.get(base_url + '/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner')

print(r.text)
# Out:
# <!doctype html>
# <html class="no-js" lang="">
# <head>
#
#     <style>html { background: #f4f4f4; } .async-hide body { opacity: 0 !important} </style>
#     <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',1500,
#     {'GTM-53B3KKW':true});</script>
# <script>
# !function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]};
# g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});
# g.o.observe({entryTypes:['longtask']})}}();
# </script>
#
#
#     <script>
#         (function() {
#             function getCookie(name) {
#               var value = "; " + document.cookie;
#               var parts = value.split("; " + name + "=");
#               if (parts.length == 2) return parts.pop().split(";").shift();
#             }
#             function replaceUrlParam(url, paramName, paramValue) {
#                 if (paramValue == null) {
#                     paramValue = '';
#                 }
#                 var pattern = new RegExp('\\b('+paramName+'=).*?(&|#|$)');
#                 if (url.search(pattern)>=0) {
#                     return url.replace(pattern,'$1' + paramValue + '$2');
#                 }
#                 url = url.replace(/[?#]$/,'');
#                 return url + (url.indexOf('?')>0 ? '&' : '?') + paramName + '=' + paramValue;
#             }
#
#             var lc = getCookie('delivery_zone')
#
#             var newHref = window.location.href
#
#             if(lc) {
#                 if(window.location.search.indexOf(lc) === -1) { // has cookie -> replace url with cookie
#                     newHref = replaceUrlParam(newHref, '_lc', lc)
#                 }
#             } else {
#                 if(window.location.search.indexOf('_lc') !== -1) { // no cookie, has url -> replace url with cookie
#                     newHref = replaceUrlParam(newHref, '_lc', '')
#                 }
#             }
#             if(newHref != window.location.href) {
#                 window.location.href = newHref
#             }
#         })()
#     </script>
#
#
#
#
#
#     <title>Đặt mua sách online giá tốt - Giao ngay trong 2h </title>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"5e70a0d5a3",applicationID:"469087689"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var a,f,c=e("handle"),u=e("loader"),s=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){a=new PerformanceObserver(r),f=new PerformanceObserver(i);try{a.observe({entryTypes:["paint"]}),f.observe({entryTypes:["largest-contentful-paint"]})}catch(p){}}if("addEventListener"in document){var l=!1,d=["click","keydown","mousedown","pointerdown","touchstart"];d.forEach(function(e){document.addEventListener(e,o,!1)})}}},{}],3:[function(e,n,t){function r(e,n){if(!i)return!1;if(e!==i)return!1;if(!n)return!0;if(!o)return!1;for(var t=o.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}n.exports={agent:i,version:o,match:r}},{}],4:[function(e,n,t){function r(e,n){var t=[],r="",o=0;for(r in e)i.call(e,r)&&(t[o]=n(r,e[r]),o+=1);return t}var i=Object.prototype.hasOwnProperty;n.exports=r},{}],5:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,i=t-n||0,o=Array(i<0?0:i);++r<i;)o[r]=e[n+r];return o}n.exports=r},{}],6:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function i(e){function n(e){return e&&e instanceof r?e:e?c(e,f,o):o()}function t(t,r,i,o){if(!l.aborted||o){e&&e(t,r,i);for(var a=n(i),f=v(t),c=f.length,u=0;u<c;u++)f[u].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function d(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){r ...
#     <meta name="description" content="Sách tiếng Anh, sách kiến thức tổng hợp, sách tâm lý, sách kinh tế, sách thiếu nhi, tạp chí, từ điển, truyện tranh... Tất cả các loại sách trong ngoài nước đều có thể tìm thấy tại Tiki.vn">
#     <meta name="keywords" content="Tiki.vn">
#     <meta name="google-signin-client_id" content="603940932442-lsh6fp6s1iqeb8i48cjhko7ai7ulrtc6.apps.googleusercontent.com">
#             <meta name="robots" content="INDEX,FOLLOW">
#
#             <meta name="viewport" content="width=1270">
#
#     <meta name="msvalidate.01" content="7B5244978F593330CE453390BC14A845" />
#     <meta name="google-site-verification" content="7GHar_W5H0cxQxHnW2L1Y6cEIgumXq2ohefKmZXOzT8" />
#     <link rel="manifest" href="/manifest.json" />
#     <link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32" />
#     <link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16" />
#     <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
#
#     <link rel="dns-prefetch" href="//tiki.vn/">
# 	<link rel="dns-prefetch" href="//tikicdn.com/">
# 	<link rel="dns-prefetch" href="//tala.tikicdn.com/">
# 	<link rel="dns-prefetch" href="//vcdn.tikicdn.com/">
#
#     <link rel="stylesheet" type="text/css" href="https://salt.tikicdn.com/desktop/dist/category.css?v=nvms_200731092307">    <meta property="og:image" content="https://tiki.vn/assets/img/tiki-home.png" />
# <meta property="og:image:width" content="200" />
# <meta property="og:image:height" content="200" />
#     <link rel="canonical" href="https://tiki.vn/nha-sach-tiki/c8322" />
# <link rel="next" href="https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=2" />
#             <link rel="apple-touch-icon" href="https://vcdn.tikicdn.com/assets/img/icon175x175.jpeg">
#
#     <script src="https://salt.tikicdn.com/desktop/js/modernizr.js"></script>
#
#     <script>
#         window.onloadCallbackStack = [];
#         window.addOnloadEvent = function(event) {
#             window.onloadCallbackStack.push(event)
#             window.onload = function() {
#                 for(var i = 0; i < window.onloadCallbackStack.length; i++) {
#                     var func = window.onloadCallbackStack[i];
#                     func();
#                 }
#             }
#         }
#     </script>
#
#
#     <!--  BEGIN GOOGLE TAGMANAGER -->
#     <!-- BEGIN: GTM DATA LAYER -->
# <script>
# 	var dataLayer = dataLayer ? dataLayer : [];
# </script>
# <!-- END: GTM DATA LAYER -->
#
# <!-- Google Tag Manager -->
# <script>
# 	// Fix gtm issue on IE/Edge
# 	function fixHistoryMethod(name) {
# 	    var oldMethod = window.history[name];
# 	    window.history[name] = function(state, title, url) {
# 	        if (url === undefined) {
# 	            oldMethod.apply(window.history, [state, title]);
# 	        } else {
# 	            oldMethod.apply(window.history, [state, title, url]);
# 	        }
# 	    }
# 	}
#
# 	fixHistoryMethod("replaceState");
# 	fixHistoryMethod("pushState");
# 	// load gtm after window onload
#
#     window.addOnloadEvent(function() {
#     	setTimeout(function() {
# 	    	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
# 		    {'gtm.start': new Date().getTime(),event:'gtm.js'}
#
# 		    );var f=d.getElementsByTagName(s)[0],
# 		    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
# 		    '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		    })(window,document,'script','dataLayer','GTM-KR9FQH');
#     	}, 3000);
#     })
# </script>
# <!-- End Google Tag Manager -->
# <!-- Export Id of GTM -->
# <script>
# 	window.tiki = window.tiki || {};
# 	if (typeof Object.defineProperty === 'function') {
# 		Object.defineProperty(window.tiki, 'gtmId', {
# 			writable: false,
# 			configurable: false,
# 			value: 'GTM-KR9FQH'
# 		});
# 	} else {
# 		window.tiki.gtmId = 'GTM-KR9FQH';
# 	}
# </script>
#
#     <!--  END GOOGLE TAGMANAGER -->
#
#     <script>
#             var isLoggedIn = false;
#         var customerId = 0;
#     </script>
#     <script type="text/javascript">
#
#         var BLUESHIFT_APP_ID = 'eaa6ba7302f37a8ff8b1a289f727c26f';
#
#     window._blueshiftid=BLUESHIFT_APP_ID;window.blueshift=window.blueshift||[];if(blueshift.constructor===Array){blueshift.load=function(){var d=function(a){return function(){blueshift.push([a].concat(Array.prototype.slice.call(arguments,0)))}},e=["identify","track","click","pageload","capture","retarget"];for(var f=0;f<e.length;f++)blueshift[e[f]]=d(e[f])};}
#     blueshift.load();
#     blueshift.pageload();
#     if(blueshift.constructor===Array){(function(){var b=document.createElement("script");b.type="text/javascript",b.async=!0,b.src=("https:"===document.location.protocol?"https:":"http:")+"//cdn.getblueshift.com/blueshift.js";var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c);})()}
#     </script>
#
#     <script type="text/javascript">
#
#         var TRACKITY_APP_ID = '1111c112a1b2531170f676e052cffpro';
#     var TRACKITY_DOMAIN = 'trackity.tiki.vn'
#
#     // init trackity sdk in bundle
#     window.trackity = window.trackity || [];
#
#     </script>
#
#
#     <script>
#                 var _siteId="638735871";
#             </script>
#
#     <!-- Ants Insight script -->
#     <script type="text/javascript">
#         (function(){ var w = window;
#         if (w.admp_event) return;
#         var a = window.admp_event =  function() {a.queue.push(arguments);};
#         a.siteId = _siteId;
#         a.track = a;
#         a.queue = [];
#         var e=document.createElement("script");
#         e.type="text/javascript",e.async=!0,e.src="//st-a.anthill.vn/insight.js";
#         var t=document.getElementsByTagName("script")[0];
#         t.parentNode.insertBefore(e,t)})();
#     </script>
#     <!-- End of Ants Insight script -->
#
#
#
#
#         <script type="text/javascript">
#     (function(i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function() {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-15036050-1', 'auto');
#
#     // Updates the tracker to use `navigator.sendBeacon` if available.
#     ga('set', 'transport', 'beacon');
#
#     // ga(function(u) {u.set('sendHitTask', function(model) {
#     //     var xhr = new XMLHttpRequest();
#     //     xhr.open('POST', 'https://www.google-analytics.com/analytics.js', true);
#     //     xhr.send(model.get('hitPayload'));
#     // });});
#
#
#         ga('require', 'GTM-53B3KKW');
#         ga('require', 'linkid');
#     ga('require', 'displayfeatures');
#     ga('require', 'ec');
#
#     if(typeof isLoggedIn !== 'undefined' && isLoggedIn){
#         // ga('set', 'userId', userId);
#         // ga('set', 'dimension1', userId);
#         // ga('set', 'dimension3', 'Yes');
#     }else{
#         // ga('set', 'dimension3', 'No');
#     }
#
#     ga(function(tracker) {
#         const clientId = tracker.get('clientId');
#         ga('set', 'dimension6', clientId);
#     });
#
#     ga('set', 'dimension7', navigator.userAgent);
# </script>
# <script>
#         </script>
#
# <script>
#         </script>
#
# <script>
#         </script>
#
# <script>
#         </script>
#
#
#
#
#             <script>
#             ga('set', 'contentGroup1', "Nh\u00e0 S\u00e1ch Tiki");
#         </script>
#
#                 <script>
#                                 </script>
#
#             <script>
#                                         ga('ec:addImpression', {
#                     'id': 2048897,
#                     'name': "Call Me By Your Name",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 1                });
#                             ga('ec:addImpression', {
#                     'id': 11119019,
#                     'name': "Oxford Advanced Learner's Dictionary 8th Edition (With Vietnamese Translation) and CD - ROM (Paperback)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 2                });
#                             ga('ec:addImpression', {
#                     'id': 50751279,
#                     'name': "Vui V\u1ebb Kh\u00f4ng Qu\u1ea1u Nha - T\u1ea3n V\u0103n",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 3                });
#                             ga('ec:addImpression', {
#                     'id': 54748899,
#                     'name': "Mu\u00f4n Ki\u1ebfp Nh\u00e2n Sinh (Many Lives - Many Times)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 4                });
#                             ga('ec:addImpression', {
#                     'id': 11232442,
#                     'name': "\u0110\u1eebng L\u1ef1a Ch\u1ecdn An Nh\u00e0n Khi C\u00f2n Tr\u1ebb",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 5                });
#                             ga('ec:addImpression', {
#                     'id': 480040,
#                     'name': "\u0110\u1eafc Nh\u00e2n T\u00e2m (Kh\u1ed5 L\u1edbn)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 6                });
#                             ga('ec:addImpression', {
#                     'id': 53434797,
#                     'name': "S\u00e1ch T\u00e0i Ch\u00ednh C\u00e1 Nh\u00e2n Cho Ng\u01b0\u1eddi Vi\u1ec7t Nam - T\u1eb7ng Kh\u00f3a h\u1ecdc Online v\u1ec1 T\u00e0i ch\u00ednh",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 7                });
#                             ga('ec:addImpression', {
#                     'id': 58340699,
#                     'name': "Th\u00e1m T\u1eed L\u1eebng Danh Conan T\u1eadp 97",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 8                });
#                             ga('ec:addImpression', {
#                     'id': 5143339,
#                     'name': "999 L\u00e1 Th\u01b0 G\u1eedi Cho Ch\u00ednh M\u00ecnh \u2013 Mong B\u1ea1n Tr\u1edf Th\u00e0nh Phi\u00ean B\u1ea3n Ho\u00e0n H\u1ea3o Nh\u1ea5t",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 9                });
#                             ga('ec:addImpression', {
#                     'id': 26114399,
#                     'name': "N\u00f3ng Gi\u1eadn L\u00e0 B\u1ea3n N\u0103ng , T\u0129nh L\u1eb7ng L\u00e0 B\u1ea3n L\u0129nh",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 10                });
#                             ga('ec:addImpression', {
#                     'id': 888553,
#                     'name': "Sapiens: L\u01b0\u1ee3c S\u1eed Lo\u00e0i Ng\u01b0\u1eddi (T\u00e1i B\u1ea3n C\u00f3 Ch\u1ec9nh S\u1eeda) ",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 11                });
#                             ga('ec:addImpression', {
#                     'id': 34271371,
#                     'name': "COMBO S\u00c1CH: KH\u01a0I D\u1eacY C\u1ea2M H\u1ee8NG H\u1eccC T\u1eacP + B\u00cd K\u00cdP H\u1eccC T\u1eacP TO\u00c0N DI\u1ec6N",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 12                });
#                             ga('ec:addImpression', {
#                     'id': 57669095,
#                     'name': "V\u1eabn L\u00e0 M\u00f9a H\u1ea1 Nh\u01b0ng Kh\u00f4ng C\u00f2n Ch\u00fang Ta (T\u1ea3n V\u0103n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 13                });
#                             ga('ec:addImpression', {
#                     'id': 54683089,
#                     'name': "S\u00e1ch Mu\u00f4n Ki\u1ebfp Nh\u00e2n Sinh T\u1eb7ng Bookmark",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 14                });
#                             ga('ec:addImpression', {
#                     'id': 14462349,
#                     'name': "C\u00e2n B\u1eb1ng C\u1ea3m X\u00fac, C\u1ea3 L\u00fac B\u00e3o Gi\u00f4ng",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 15                });
#                             ga('ec:addImpression', {
#                     'id': 378448,
#                     'name': "Nh\u00e0 Gi\u1ea3 Kim",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 16                });
#                             ga('ec:addImpression', {
#                     'id': 49459956,
#                     'name': "Ch\u1ee7 Ngh\u0129a Kh\u1eafc K\u1ef7 - Phong C\u00e1ch S\u1ed1ng B\u1ea3n L\u0129nh V\u00e0 B\u00ecnh Th\u1ea3n",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 17                });
#                             ga('ec:addImpression', {
#                     'id': 10005245,
#                     'name': "\u0110\u00e0n \u00d4ng Sao H\u1ecfa \u0110\u00e0n B\u00e0 Sao Kim",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 18                });
#                             ga('ec:addImpression', {
#                     'id': 46107062,
#                     'name': "T\u00f4i Quy\u1ebft \u0110\u1ecbnh S\u1ed1ng Cho Ch\u00ednh T\u00f4i (T\u1eb7ng K\u00e8m 1 S\u1ed5 To Do List 2020)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 19                });
#                             ga('ec:addImpression', {
#                     'id': 57870426,
#                     'name': "S\u1ee9c M\u1ea1nh C\u1ee7a Ng\u00f4n T\u1eeb\u00a0(T\u1eb7ng K\u00e8m 1 Photocard Mintbooks Limited)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 20                });
#                             ga('ec:addImpression', {
#                     'id': 56692532,
#                     'name': "T\u00f4i T\u1eebng Ngh\u0129 M\u1ecdi Th\u1ee9 S\u1ebd \u1ed4n Khi Tr\u1edf Th\u00e0nh Ng\u01b0\u1eddi L\u1edbn (T\u1eb7ng K\u00e8m 1 Bookmark)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 21                });
#                             ga('ec:addImpression', {
#                     'id': 3014291,
#                     'name': "M\u00e1y T\u00ednh Khoa H\u1ecdc Casio FX-580VN X",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 22                });
#                             ga('ec:addImpression', {
#                     'id': 54614795,
#                     'name': "Ki\u00ean Tr\u00ec \u1eaet \u0110\u01b0\u1ee3c \u0110\u1ec1n \u0110\u00e1p (T\u00e1i B\u1ea3n 2020)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 23                });
#                             ga('ec:addImpression', {
#                     'id': 579823,
#                     'name': "Nh\u00e0 L\u00e3nh \u0110\u1ea1o Kh\u00f4ng Ch\u1ee9c Danh",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 24                });
#                             ga('ec:addImpression', {
#                     'id': 15415622,
#                     'name': "H\u00e0nh Tr\u00ecnh V\u1ec1 Ph\u01b0\u01a1ng \u0110\u00f4ng (T\u00e1i B\u1ea3n 2019)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 25                });
#                             ga('ec:addImpression', {
#                     'id': 10694712,
#                     'name': "T\u00f4i T\u00e0i Gi\u1ecfi - B\u1ea1n C\u0169ng Th\u1ebf (T\u00e1i B\u1ea3n 2019 )",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 26                });
#                             ga('ec:addImpression', {
#                     'id': 7833728,
#                     'name': "D\u1ea1y Con L\u00e0m Gi\u00e0u (T\u1eadp 1) - \u0110\u1ec3 Kh\u00f4ng C\u00f3 Ti\u1ec1n V\u1eabn T\u1ea1o Ra Ti\u1ec1n - Cha Gi\u00e0u Cha Ngh\u00e8o (T\u00e1i B\u1ea3n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 27                });
#                             ga('ec:addImpression', {
#                     'id': 11081535,
#                     'name': "Combo 999 L\u00e1 Th\u01b0 G\u1eedi Cho Ch\u00ednh M\u00ecnh - T\u1eb7ng k\u00e8m bookmark (Tr\u1ecdn b\u1ed9 2 t\u1eadp)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 28                });
#                             ga('ec:addImpression', {
#                     'id': 970950,
#                     'name': "C\u00f4ng Ph\u00e1 To\u00e1n 3 ",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 29                });
#                             ga('ec:addImpression', {
#                     'id': 985266,
#                     'name': "\u0110\u1eebng Bao Gi\u1edd \u0110i \u0102n M\u1ed9t M\u00ecnh (T\u00e1i B\u1ea3n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 30                });
#                             ga('ec:addImpression', {
#                     'id': 8835159,
#                     'name': "\u0110\u1eddi Ng\u1eafn \u0110\u1eebng Ng\u1ee7 D\u00e0i (T\u00e1i B\u1ea3n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 31                });
#                             ga('ec:addImpression', {
#                     'id': 5852521,
#                     'name': "Combo C\u00e0 Ph\u00ea C\u00f9ng Tony v\u00e0 Tr\u00ean \u0110\u01b0\u1eddng B\u0103ng",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 32                });
#                             ga('ec:addImpression', {
#                     'id': 49249526,
#                     'name': "Thi\u1ebft K\u1ebf Cu\u1ed9c \u0110\u1eddi Th\u1ecbnh V\u01b0\u1ee3ng - Design a Prosperous Life",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 33                });
#                             ga('ec:addImpression', {
#                     'id': 1476937,
#                     'name': "D\u00e1m B\u1ecb Gh\u00e9t",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 34                });
#                             ga('ec:addImpression', {
#                     'id': 22782784,
#                     'name': "H\u1ed9p b\u00fat \u0111a zi n\u0103ng 5 in 1",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 35                });
#                             ga('ec:addImpression', {
#                     'id': 1694077,
#                     'name': "B\u1ea1n \u0110\u1eaft Gi\u00e1 Bao Nhi\u00eau?",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 36                });
#                             ga('ec:addImpression', {
#                     'id': 599055,
#                     'name': "T\u00f4i T\u1ef1 H\u1ecdc",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 37                });
#                             ga('ec:addImpression', {
#                     'id': 4040663,
#                     'name': "25 Chuy\u00ean \u0110\u1ec1 Ng\u1eef Ph\u00e1p Ti\u1ebfng Anh Tr\u1ecdng T\u00e2m \u2013 (T\u1eadp 1)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 38                });
#                             ga('ec:addImpression', {
#                     'id': 7718733,
#                     'name': "Tu\u1ed5i Tr\u1ebb \u0110\u00e1ng Gi\u00e1 Bao Nhi\u00eau (T\u00e1i B\u1ea3n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 39                });
#                             ga('ec:addImpression', {
#                     'id': 20444622,
#                     'name': "C\u1ea9m Nang C\u1ea5u Tr\u00fac Ti\u1ebfng Anh",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 40                });
#                             ga('ec:addImpression', {
#                     'id': 572433,
#                     'name': "T\u1eeb T\u1ed1t \u0110\u1ebfn V\u0129 \u0110\u1ea1i",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 41                });
#                             ga('ec:addImpression', {
#                     'id': 57587819,
#                     'name': "Tui Ship \u0110\u1ed1i Th\u1ee7 X Tui",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 42                });
#                             ga('ec:addImpression', {
#                     'id': 31509726,
#                     'name': "L\u00e0m B\u1ea1n V\u1edbi B\u1ea7u Tr\u1eddi (B\u00eca M\u1ec1m) (T\u1eb7ng K\u00e8m Khung \u1ea2nh S\u1ed1 L\u01b0\u1ee3ng C\u00f3 H\u1ea1n)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 43                });
#                             ga('ec:addImpression', {
#                     'id': 56307244,
#                     'name': "Power Vs Force - Tr\u01b0\u1eddng N\u0103ng L\u01b0\u1ee3ng V\u00e0 Nh\u1eefng Nh\u00e2n T\u1ed1 Quy\u1ebft \u0110\u1ecbnh Tinh Th\u1ea7n V\u00e0 S\u1ee9c Kh\u1ecfe Con Ng\u01b0\u1eddi",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 44                });
#                             ga('ec:addImpression', {
#                     'id': 1005148,
#                     'name': "Tony Bu\u1ed5i S\u00e1ng - Tr\u00ean \u0110\u01b0\u1eddng B\u0103ng (T\u00e1i B\u1ea3n 2017)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 45                });
#                             ga('ec:addImpression', {
#                     'id': 6201209,
#                     'name': "S\u1ed1ng Th\u1ef1c T\u1ebf Gi\u1eefa \u0110\u1eddi Th\u1ef1c D\u1ee5ng",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 46                });
#                             ga('ec:addImpression', {
#                     'id': 22984216,
#                     'name': "Gi\u1ea5y v\u1ebd M\u00e0u N\u01b0\u1edbc Nabii Aqua Fat 300gsm",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 47                });
#                             ga('ec:addImpression', {
#                     'id': 3953475,
#                     'name': "Nu\u00f4i Con Kh\u00f4ng Ph\u1ea3i L\u00e0 Cu\u1ed9c Chi\u1ebfn 2 (Tr\u1ecdn B\u1ed9 3 T\u1eadp)",
#                     'list': "Category | Nh\u00e0 S\u00e1ch Tiki",
#                     'position': 48                });
#                     </script>
#
#
#
#
#
#
# <script type="text/javascript">
#
#
# </script>
#
# <script type="text/javascript">
#     (function () {
#         try {
#             function getCookie(name) {
#               var value = "; " + document.cookie;
#               var parts = value.split("; " + name + "=");
#               if (parts.length == 2) return parts.pop().split(";").shift();
#             }
#             var trackityId = getCookie('_trackity');
#             if(trackityId) {
#                 ga('set', 'dimension38', trackityId);
#             }
#
#             try {
#                 var customer_id = JSON.parse(localStorage.getItem('access-token'))['customer_id'];
#                 if(customer_id > 0) {
#                     ga('set', 'userId', customer_id);
#                     ga('set', 'dimension1', customer_id.toString());
#                     ga('set', 'dimension3', 'Yes');
#                 } else {
#                    ga('set', 'dimension3', 'No');
#                 }
#             } catch(e) {
#                 ga('set', 'dimension3', 'No');
#             }
#
#         } catch(e) {
#
#         }
#     })()
# </script>
#
# <script type="text/javascript">
#             ga('send', 'pageview');
#     </script>
#
#
#
#
#
#                 <!-- Hotjar Tracking Code for tiki.vn -->
# <!-- <script>
# (function(h,o,t,j,a,r){
# h.hj=h.hj||function()
# {(h.hj.q=h.hj.q||[]).push(arguments)}
# ;
# h._hjSettings=
# {hjid:8182,hjsv:5}
# ;
# a=o.getElementsByTagName('head')[0];
# r=o.createElement('script');r.async=1;
# r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# a.appendChild(r);
# })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
# </script> -->
#
#
#
#     <script src='https://cdn.onesignal.com/sdks/OneSignalSDK.js' async></script>
# <script>
#     window.safariWebId = "web.onesignal.auto.3a869b75-1942-4792-8237-9de8041a4c17";
#     window.OneSignalAppId = "279c6749-1d3d-4b78-bc95-af0f0d4ce1de";
#     window.OneSignal = window.OneSignal || [];
#     window.OneSignal.push(function() {
#         window.OneSignal.init({
#             appId: window.OneSignalAppId ,
#             safari_web_id: window.safariWebId
#         });
#     });
# </script>
#
#
#     <!--  BEGIN GOOGLE TAGMANAGER FOR TEST-->
#         <!--  END GOOGLE TAGMANAGER FOR TEST-->
#
#
#                     <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500&amp;subset=vietnamese" rel="stylesheet">
# </head>
# <body class="badge-v2 tiki-categories">
#
#
#
#     <!-- Google Tag Manager -->
#     <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-KR9FQH" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <script>
#     window.addOnloadEvent(function() {
#         setTimeout(function() {
#             (function(d, s, id){
#                 return;
#                 var js, fjs = d.getElementsByTagName(s)[0];
#                 if (d.getElementById(id)) {return;}
#                 js = d.createElement(s); js.id = id;
#                 js.src = "//connect.facebook.net/vi_VN/sdk.js";
#                 fjs.parentNode.insertBefore(js, fjs);
#             }(document, 'script', 'facebook-jssdk'));
#         }, 3000);
#     })
# </script>
#
#
#                         <div id="top-bar-container" class="hidden-xs hidden-sm">
#
# </div>    <!-- Desktop Header -->
#     <header id="header" class="nav-collapse">
#         <div class="top-promo">
#     <div class="container">
#         <div class="right">
#             <!-- Ticketbox -->
# <a
#     class="top-label"
#     href="/ticketbox?src=header_ticketbox" >
#     <img
#         style="margin-top: -1px;"
#         src="https://salt.tikicdn.com/ts/upload/42/f9/5e/7ccf8b09de0e051cc9054bd535f7b1a1.png"
#         alt="Ticketbox"
#         width="18"
#       />
#     <span>Ticketbox</span>
# </a>
#
# <!-- Add icon extension -->
# <div class="tiki-assistant__wrap">
#     <a class="tiki-assistant" target="_blank" href="https://chrome.google.com/webstore/detail/tiki-assistant/ncpaceoemnbcjffjpjcgnbaklmkhdmak?hl=en-US&gl=VN&authuser=1">
#         <img
#             src="https://salt.tikicdn.com/media/upload/2019/01/30/1f41899d3b37d9aa3197b8839f6916fe.png"
#             srcset="https://salt.tikicdn.com/media/upload/2019/01/30/1f41899d3b37d9aa3197b8839f6916fe.png 1x, https://salt.tikicdn.com/media/upload/2019/01/30/736dfae48db88034a73e7fdb7f72756b.png 2x"
#             alt="Tiki Assistant"
#         >
#         <span>Trợ lý Tiki</span>
#     </a>
#     <div class="tiki-assistant__tooltip">
#         <p><a target="_blank" href="https://chrome.google.com/webstore/detail/tiki-assistant/ncpaceoemnbcjffjpjcgnbaklmkhdmak?hl=en-US&gl=VN&authuser=1">Tiki Assistant</a> là tiện ích chạy trực tiếp trên trình duyệt Chrome -  giúp gợi ý & tìm kiếm nhanh các sản phẩm tốt nhất trên Tiki, phù hợp với nhu cầu tìm kiếm sản phẩm của bạn.</p>
#         <p>Cách sử dụng: Bạn không cần phải làm gì khác sau khi cài đặt tiện ích này. Khi bạn tìm kiếm sản phẩm, tiện ích Tiki Assistant sẽ tự động gợi ý các sản phẩm phù hợp (nếu có). </p>
#     </div>
# </div>
# <!-- end -->
#
#     <a class="top-label" target="_blank"
#         href="https://tiki.vn/chuong-trinh/uu-dai-doi-tac?src=header_partner_offers"
#         source="header_partner_offers"
#         title="Ưu đ&atilde;i đối t&aacute;c"
#         onclick=""
#         >
#         <i class="tikicon icon-uu-dai-hop-tac"></i>        Ưu đãi đối tác    </a>
#
#     <a class="top-label" target="_blank"
#         href="https://tiki.vn/booking-hotel?src=header_hotels"
#         source="header_hotels"
#         title=" Đặt kh&aacute;ch sạn"
#         onclick=""
#         >
#         <i class="tikicon icon-booking_dot_com"></i>         Đặt khách sạn    </a>
#
#     <a class="top-label" target="_blank"
#         href="https://tiki.vn/dat-ve-may-bay?src=header_flights"
#         source="header_flights"
#         title="Đặt v&eacute; m&aacute;y bay"
#         onclick=""
#         >
#         <i class="tikicon icon-gotadi"></i>        Đặt vé máy bay    </a>
#
#     <a class="top-label" target="_blank"
#         href="https://tiki.vn/deal-hot?src=header_promotion"
#         source="header_promotion"
#         title="Deal SỐC giảm gi&aacute; mỗi ng&agrave;y"
#         onclick="ga('send','event','tiki-hot','click','header-label')"
#         >
#         <i class="ico ico-fire"></i>        Khuyến Mãi HOT    </a>
#
#     <a class="top-label" target="_blank"
#         href="https://tiki.vn/hang-ngoai-nhap?src=header_international"
#         source="header_international"
#         title="H&agrave;ng quốc tế"
#         onclick=""
#         >
#         <i class="tikicon icon-global-18"></i>        Hàng quốc tế    </a>
#
#             <div class="sell-with-tiki top-label">
#     <a target="_blank"
#         href="/ban-hang-cung-tiki?ref=header-dropdown&src=header_sell_with_tiki"
#         title="Kinh doanh cùng Tiki"
#         onclick="ga('send','event','tiki-sell-with-tiki','click','header-label');">
#         <i class="tikicon icon-money_bag"></i>
#         Bán hàng cùng Tiki <i class="tikicon icon-arrow-down"></i>
#     </a>
#     <div class="collapse">
#         <div class="title">Bán hàng hiệu quả cùng Tiki</div>
#         <ul>
#             <li>
#                 Hơn <b>30 triệu lượt truy cập</b> hàng tháng với hơn <b>40% là khách hàng trung thành</b>
#             </li>
#             <li>
#                 Trung bình <b>giao hàng dưới 2 ngày</b>, nhận tiền nhanh hơn, không làm đọng vốn
#             </li>
#             <li>
#                 Tỉ lệ <b>huỷ đơn hàng dưới 3%</b>, thấp nhất trên thị trường
#             </li>
#             <li>
#                 Kiểm soát chất lượng hàng hoá. Đảm bảo <b>cạnh tranh lành mạnh, không hàng giả, hàng nhái</b>
#             </li>
#         </ul>
#         <a target="_blank" href="/ban-hang-cung-tiki?ref=header-dropdown&src=header_sell_with_tiki" title="Kinh doanh cùng Tiki"  class="register"
#         	onclick="ga('send','event','tiki-sell-with-tiki','click','header-label');">ĐĂNG KÝ NGAY</a>
#     </div>
# </div>
#
#
#
#         </div>
#     </div>
# </div>        <div class="header-form-container">
#             <div class="container">
#                 <a href="https://tiki.vn/?src=header_tiki" class="logo">
#                     <i class="tikicon icon-tiki_short"></i>
#                 </a>
#
#                 <div class="form-search">
#                     <form id="search_form" action="https://tiki.vn/search" method="get">
#                         <div class="search-wrap">
#                             <div class="input">
#                                 <div class="flex">
#                                     <input type="text" name="q" autocomplete="off" value=""  placeholder="Tìm sản phẩm, danh mục hay thương hiệu mong muốn ...">
#                                                                             <script>
#                                             var searchCategoryPath = "\/nha-sach-tiki\/c8322"                                        </script>
#                                         <div class="checkbox-wrap">
#                                             <a href="javascript:" title="Trong Nhà Sách Tiki">
#                                                 <label class="checkbox">
#                                                     <input type="checkbox"
#                                                     class="search-in-category">
#                                                     <span class="ico"></span>
#                                                     <b>Trong:</b> Nhà Sách Tiki                                                </label>
#                                             </a>
#                                         </div>
#                                                                     </div>
#                             </div>
#                             <button type="submit">
#                                 <i class="tikicon icon-search"></i>
#                                 <span>Tìm kiếm</span>
#                             </button>
#                         </div>
#                     </form>
#                     <div id="search-seller" ></div>
#                     <div id="search-suggestion" style="display: none"></div>
#                     <div id="search-autocomplete" style="display: none"></div>
#                 </div>
#                 <div class="header-link">
#                     <a rel="nofollow" href="https://tiki.vn/sales/order/history?src=header_orders" title="Kiểm tra trạng thái Đơn hàng của bạn" class="tracking-order item">
#                         <i class="icon-style-1 tikicon icon-tracking"></i>
#                         Theo dõi<br>đơn hàng
#                     </a>
#                     <div class="noti-item tracking-noti item" id="header-noti">
#                        <div>
#                             <div>
#                                 <i class="icon-style-1 tikicon icon-notification"></i>
#                                 Thông báo<br/>của tôi
#                             </div>
#                        </div>
#                     </div>
#                     <div class="user-profile item" id="header-user">
#                         <div>
#     <i class="icon-style-1 tikicon icon-user"></i>
#     <b class="user-name loading">
#     </b>
#     <br/>
#     <small>Tài khoản</small>
# </div>
# <div class="box">
#     <ul class="user-ajax-guest" style="display: none">
#         <li id="login_link">
#             <a href="#" data-toggle="modal" data-target="#login-form" title="Đăng Nhập" class="user-name-login">
#                 <span class="text">Đăng nhập</span>
#             </a>
#         </li>
#         <li class="user-name-register">
#             <a href="#" title="Tạo tài khoản mới" data-toggle="modal" data-target="#register-form">
#                 <span class="text">Tạo tài khoản</span>
#             </a>
#         </li>
#         <li id="login_fb_link">
#             <a
#                 class="user-name-loginfb"
#                 title="Đăng nhập bằng Facebook"
#                 href="javascript: void(0)"
#                 data-url="https://tiki.vn/customer/account/loginFacebook">
#                 <span class="icon">
#                     <i class="ico ico-facebook"></i>
#                 </span>
#                 <span class="text">Đăng nhập bằng Facebook</span>
#             </a>
#         </li>
#         <li id="login_google_link">
#             <a class="user-name-login-google" title="Đăng nhập bằng Google" href="javascript: void(0)" data-url="https://tiki.vn/customer/account/login_google?reset&ref=nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner">
#                 <span class="icon"><i class="ico ico-google"></i></span>
#                 <span class="text">Đăng nhập bằng Google</span>
#             </a>
#         </li>
#         <li id="login_zalo_link">
#             <a class="user-name-login-zalo" title="Đăng nhập bằng Zalo" href="javascript: void(0)" data-url="https://tiki.vn/customer/account/loginZalo?ref=nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner">
#                 <img src="https://tiki.vn/assets/img/svg/zaloicon.svg" />
#                 <span class="text">Đăng nhập bằng Zalo</span>
#             </a>
#         </li>
#     </ul>
#
#     <ul class="user-ajax-customer" style="display: none">
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/sales/order/history/" title="Đơn hàng của tôi">
#                 Đơn hàng của tôi
#             </a>
#         </li>
#         <li class="book-profile">
#         </li>
#         <li class="notification-count">
#             <a rel="nofollow" href="https://tiki.vn/customer/notification/" title="Thông báo của tôi">
#                 Thông báo của tôi
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/customer/account/" title="Tài khoản của tôi">
#                 Tài khoản của tôi
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/customer/save_for_later/" title="Để dành mua sau">
#                 Để dành mua sau
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/danh-rieng-cho-ban" title="Sản phẩm bạn đã xem">
#                 Sản phẩm bạn đã xem
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/nhan-xet-san-pham-ban-da-mua" title="Nhận xét sản phẩm đã mua">
#                 Nhận xét sản phẩm đã mua
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/customer/wishlist/" title="Danh sách yêu thích">
#                 Danh sách yêu thích
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/customer/review/" title="Đánh giá của tôi">
#                 Đánh giá của tôi
#             </a>
#         </li>
#         <li class="reward-point">
#             <a rel="nofollow" href="https://tiki.vn/customer/reward/" title="Thông tin Tiki Xu">
#                 Thông tin Tiki Xu
#                 <br>
#             </a>
#         </li>
#         <li class="my-bookcare">
#             <a rel="nofollow" href="https://tiki.vn/customer/bookcare/" title="Book Care của tôi">
#                 Book Care của tôi
#                 <br>
#             </a>
#         </li>
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/doi-tra-de-dang" title="Hướng dẫn đổi trả">
#                 Đổi trả dễ dàng
#             </a>
#         </li>
#
#         <li class="tiki-friends hide">
#             <a rel="nofollow" href="https://tiki.vn/tikifriends/customer/#tiki-friends" title="Affiliate">Tiki Friends <img src="https://salt.tikicdn.com/assets/img/new-icon-red.png" class="badge-new"></a>
#         </li>
#
#         <li class="tiki-first-user hide">
#             <a rel="nofollow" href="https://tiki.vn/tikifirst/customer" title="Tiki First">
#                 Tiki First
#             </a>
#         </li>
#
#         <li>
#             <a rel="nofollow" href="https://tiki.vn/customer/account/logout" title="Thoát tài khoản">
#                 Thoát tài khoản
#             </a>
#         </li>
#     </ul>
# </div>
#                     </div>
#                      <div id="header-cart">
#                          <a rel="nofollow" href="https://tiki.vn/checkout/cart?src=header_cart" class="header-cart item">
#                             <i class="icon-style-1 tikicon icon-cart"></i>
#                             Giỏ hàng
#                             <span class="cart-count hide">0</span>
#                         </a>
#                      </div>
#                      <!-- Tooltip Link social -->
#                      <div class="box-social">
#                         <div class="popup-social">
#                             <span>
#                                 Kết nối tài khoản mạng xã hội để đăng nhập nhanh chóng, dễ dàng hơn.
#                             </span>
#                             <i class="tikicon icon-facebook-small"></i>
#                             <i class="tikicon icon-google-small"></i>
#                             <i class="tikicon icon-zalo-small"></i>
#
#                             <a class="btn-link-now" href="https://tiki.vn/customer/account/edit" title="Liên kết ngay">Liên kết ngay</a>
#                             <a class="close" href="" title="Đóng"></a>
#                         </div>
#                      </div>
#                 </div>
#             </div>
#         </div>
#         <div class="main-nav">
#             <div class="container">
#
# <nav class="main-nav-wrap">
#     <a href="javascript:" class="main-nav-toggle">
#         <i class="tikicon icon-burger-menu"></i>
#         <span class="long">DANH MỤC SẢN PHẨM</span>
#         <span class="short">DANH MỤC</span>
#     </a>
#     <ul class="v2">
#                                 <li>
#                 <a href="https://tiki.vn/dien-thoai-may-tinh-bang/c1789" class="">
#                     <span class="icon-wrap">
#                         <i class="lv1-icon tikicon icon-main-menu-cellphone"></i>
#                     </span>
#                     <span>Điện Thoại - Máy Tính Bảng</span>
#                 </a>
#                                     <div class="nav-sub">
#                         <ul>
#                                                             <li>
#                                 <div class="nav-sub-list-box">
#                                                                                                                                                                                                                                                             <span class="bold ">
#                                                     Xu hướng<i class="tikicon icon-new"></i>                                                </span>
# ...
#                                 <span class="price-regular">319.000đ</span>
#                                                     <span class="sale-tag sale-tag-square">-39%</span>
#                             </p>
#         </div>
#
#
#                     <div class="price-tag-wrap">
#                             </div>
#
#
#                     <div class="review-wrap">
#                 <p class="rating">
#                     <span class="rating-content">
#                         <i class="star"></i>
#                         <i class="star"></i>
#                         <i class="star"></i>
#                         <i class="star"></i>
#                         <i class="star"></i>
#                         <span style="width:96%">
#                             <i class="star"></i>
#                             <i class="star"></i>
#                             <i class="star"></i>
#                             <i class="star"></i>
#                             <i class="star"></i>
#                         </span>
#                     </span>
#                 </p>
#                                     <p class="review">(445 nhận xét)</p>
#                             </div>
#
#
#
#
#
#         <div class="ship-label-wrapper">
#
#
#
#                                                 </div>
#
#
#
#
#     </a>
#     </div>
#
#                                             </div>
#
#
# <script>
#     var catalogPaging = {
#         pageNum: 1,
#         limitOnPage: 48,
#         totalResults: 142303    };
# </script>
#
#     <div class="list-pager">
#         <ul>
#
#                                 <li><span class="current">1</span></li>
#                                             <li><a class="normal" href="/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=2">2</a>
#                                                     <li><a class="normal" href="/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=3">3</a>
#                                                     <li><a class="normal" href="/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=4">4</a>
#                                                     <li><a class="normal" href="/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=5">5</a>
#
#                             <li><a rel="next" class="next" href="/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=2"><i class="ico ico-arrow-next"></i></a></li>
#                 </ul>
#     </div>
#
#                                         <div class="category-bottom-banner-wrap">
#                         <a class="impress-banner" rel="nofollow" href="https://tiki.vn/chuong-trinh/mo-the-tikicard?src=category_bottom_banner_group" title="TikiCARD_UnderCate" target="_blank" data-banner-id="45881" data-banner-title="TikiCARD_UnderCate" data-banner-group-code="category_bottom_banner_group">
#                 <img src="https://salt.tikicdn.com/ts/banner/3e/7b/aa/d7f248ba9dcce0bd83bd73c04af23a39.png" alt="TikiCARD_UnderCate" class="img-responsive">
#             </a>
#             </div>
#                     <div class="box-recentlyviewed-product" id="box-recentlyviewed-product" data-impress-list-title="Category | Sản phẩm bạn đã xem"></div>
#                             </div>
#
#
#                          <div class="advisory-posts-box hide">
# </div>
# <input name="advisory-api-url" type="hidden" value="https://tiki.vn/tu-van/?api" />
# <input name="advisory-post-limit" type="hidden" value="8" />
#         </div>
#     </div>
# </div>
#
#
#
#
#     <footer id="footer">
#         <!-- Begin MailChimp Signup Form -->
#         <div class="tiki-newsletter">
#             <div class="container">
#                 <div class="row">
#                     <div class="col-lg-12 clearfix">
#                         <div class="tiki-newsletter-title clearfix">
#                             <i class="tikicon icon-newsletter"></i>
#                             <h3>Đăng ký nhận bản tin Tiki</h3>
#                             <h5>Đừng bỏ lỡ hàng ngàn sản phẩm và chương trình siêu hấp dẫn</h5>
#                         </div>
#                         <div class="mc-field-group">
#                             <input type="email" placeholder="Địa chỉ email của bạn" class="tiki-home-email form-control" id="mce-EMAIL">
#                             <span class="tiki-newsletter-helper"></span>
#                         </div>
#                         <button class="button btn btn-home-newsletter" data-index="0">Đăng ký</button>
#                     </div>
#                 </div>
#             </div>
#         </div>
#         <!--End mc_embed_signup-->
#         <hr class="line-bg-body" />
#         <div class="list-footer-nav">
#             <div class="container">
#                 <div class="footer-nav" style="margin-right: 15px;width: 262px;">
#                     <h4>HỖ TRỢ KHÁCH HÀNG</h4>
#                     <p class="hotline-number">
#                         Hotline chăm sóc khách hàng: <a href="tel:19006035">1900-6035</a><br/>
#                         <small>(1000đ/phút , 8-21h kể cả T7, CN)</small>
#                     </p>
#                     <div class="nav-list">
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi" target="_blank">Các câu hỏi thường gặp</a>
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi/requests/new" target="_blank">Gửi yêu cầu hỗ trợ</a>
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi/categories/200126644" target="_blank">Hướng dẫn đặt hàng</a>
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi/categories/200123960" target="_blank">Phương thức vận chuyển</a>
#                         <a rel="nofollow" href="https://tiki.vn/doi-tra-de-dang" target="_blank">Chính sách đổi trả</a>
#                         <a rel="nofollow" href="https://tiki.vn/chuong-trinh/tra-gop" target="_blank">Hướng dẫn mua trả góp</a>
#                         <a rel="nofollow" href="https://hotro.tiki.vn/hc/vi/articles/360000822643" target="_blank">Chính sách hàng nhập khẩu</a>
#
#                         <p class="hotline-number-normal">
#                             Hỗ trợ khách hàng: <a href="mailto:hotro@tiki.vn">hotro@tiki.vn</a>
#                         </p>
#
#                         <p class="hotline-number-normal">
#                             Báo lỗi bảo mật: <a href="mailto:security@tiki.vn">security@tiki.vn</a>
#                         </p>
#
#                     </div>
#                 </div>
#                 <div class="footer-nav">
#                     <h4>VỀ TIKI</h4>
#                     <div class="nav-list">
#                         <a rel="nofollow" href="https://hotro.tiki.vn/hc/vi/articles/201710754-Tiki-Xu-l%C3%A0-g%C3%AC-Gi%C3%A1-tr%E1%BB%8B-quy-%C4%91%E1%BB%95i-nh%C6%B0-th%E1%BA%BF-n%C3%A0o-" target="_blank">Giới thiệu Tiki</a>
#                         <a rel="nofollow" href="http://tuyendung.tiki.vn" target="_blank">Tuyển Dụng</a>
#                         <a rel="nofollow" href="https://tiki.vn/bao-mat-thanh-toan" target="_blank">Chính sách bảo mật thanh toán</a>
#                         <a rel="nofollow" href="https://tiki.vn/bao-mat-thong-tin-ca-nhan" target="_blank">Chính sách bảo mật thông tin cá nhân</a>
#                         <a rel="nofollow" href="https://hotro.tiki.vn/hc/vi/articles/115005575826" target="_blank">Chính sách giải quyết khiếu nại</a>
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi/articles/201971214" target="_blank">Điều khoản sử dụng</a>
#                         <a rel="nofollow" href="http://hotro.tiki.vn/hc/vi/articles/204153170-Các-bước-sử-dụng-Tiki-xu-và-Mã-giảm-giá" target="_blank">Giới thiệu Tiki Xu</a>
#                         <a rel="nofollow" href="https://tiki.vn/chuong-trinh/ban-hang-doanh-nghiep" target="_blank">Bán hàng doanh nghiệp</a>
#                     </div>
#                 </div>
#                 <div class="footer-nav">
#                     <h4>HỢP TÁC VÀ LIÊN KẾT</h4>
#                     <div class="nav-list">
#                         <a rel="nofollow" href="https://tiki.vn/quy-che-hoat-dong-sgdtmdt" target="_blank">Quy chế hoạt động Sàn GDTMĐT</a>
#                         <!-- <a rel="nofollow" href="http://www.foody.vn" target="_blank">Foody.vn - Ăn gì ở đâu</a>
#                         <a rel="nofollow" href="http://www.ivivu.com" target="_blank">iVIVU.com - Đặt khách sạn giá rẻ</a> -->
#                         <a rel="nofollow" href="https://tiki.vn/ban-hang-cung-tiki" target="_blank">Bán hàng cùng Tiki</a>
#                     </div>
#                     <!-- <div class="nav-other partner">
#                         <a rel="nofollow" href="http://www.foody.vn" target="_blank">
#                             <img src="https://salt.tikicdn.com/assets/img/icon/logo-foody-vietnam@3x.png" />
#                         </a>
#                         <a rel="nofollow" href="http://www.ivivu.com" target="_blank">
#                             <img src="https://salt.tikicdn.com/assets/img/icon/logo-ivivu@3x.png" />
#                         </a>
#                     </div> -->
#                 </div>
#                 <div class="footer-nav">
#                     <h4>PHƯƠNG THỨC THANH TOÁN</h4>
#                     <div class="nav-other payment">
#                         <i class="tikicon icon-visa"></i>
#                         <i class="tikicon icon-mastercard"></i>
#                         <i class="tikicon icon-jcb"></i>
#                         <i class="tikicon icon-cash"></i>
#                         <i class="tikicon icon-internet-banking"></i>
#                         <i class="tikicon icon-installment"></i>
#                     </div>
#                 </div>
#                 <div class="footer-nav">
#                     <h4>KẾT NỐI VỚI CHÚNG TÔI</h4>
#                     <div class="nav-other social-conn">
#                         <a rel="nofollow" href="https://www.facebook.com/tiki.vn/" target="_blank" title="Facebook">
#                             <i class="tikicon icon-fb"></i>
#                         </a>
#                         <a rel="nofollow" href="https://www.youtube.com/user/TikiVBlog" target="_blank" title="Youtube">
#                             <i class="tikicon icon-youtube"></i>
#                         </a>
#                         <a rel="nofollow" href="http://zalo.me/589673439383195103" target="_blank" title="Zalo">
#                             <i class="tikicon icon-footer-zalo"></i>
#                         </a>
#                         <!-- <a rel="nofollow" href="" target="_blank">
#                             <img src="https://salt.tikicdn.com/assets/img/svg/ic-instagram.svg" />
#                         </a>
#                         <a rel="nofollow" href="" target="_blank">
#                             <img src="https://salt.tikicdn.com/assets/img/svg/ic-linkedin.svg" />
#                         </a> -->
#                     </div>
#                     <h4 class="appstore-title">TẢI ỨNG DỤNG TRÊN ĐIỆN THOẠI</h4>
#                     <div class="nav-other app-store">
#                         <a rel="nofollow" href="https://itunes.apple.com/vn/app/id958100553" target="_blank">
#                             <i class="tikicon icon-appstore"></i>
#                         </a>
#                         <a rel="nofollow" href="https://play.google.com/store/apps/details?id=vn.tiki.app.tikiandroid" target="_blank">
#                             <i class="tikicon icon-playstore"></i>
#                         </a>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#         <hr class="line-bg-body" />
#
#         <address class="footer-address">
#             <div class="container">
#                 <div class="address-office">
#                     <i class="tikicon icon-location"></i>
#                     <div class="info-address">
#                         <p class="add-real">
#                             <b>Địa chỉ văn phòng:</b>
#                             52 Út Tịch, phường 4, quận Tân Bình, thành phố Hồ Chí Minh
#                         </p>
#                         <p>
#                             Tiki nhận đặt hàng trực tuyến và giao hàng tận nơi, chưa hỗ trợ mua và nhận hàng trực tiếp tại văn phòng hoặc trung tâm xử lý đơn hàng
#                         </p>
#                     </div>
#                 </div>
#                 <div class="address-service">
#                     <div class="info-address">
#                         <p class="add-real">
#                             <!-- <b>Địa chỉ gửi hàng đổi/trả/bảo hành:</b>
#                             Trung tâm xử lý đơn hàng TIKI - 367/F370 khu A75 Bạch Đằng, P.2, Q.Tân Bình, TP. Hồ Chí Minh -->
#                         </p>
#                         <p>
#
#                         </p>
#                     </div>
#                 </div>
#             </div>
#         </address>
#
#         <div class="footer-cpy-right">
#             <div class="container">
#                 <div class="cpy-right-info">
#                     <h5>&copy; 2016 - Bản quyền của Công Ty Cổ Phần Ti Ki - Tiki.vn</h5>
#                     <p>Giấy chứng nhận Đăng ký Kinh doanh số 0309532909 do Sở Kế hoạch và Đầu tư Thành phố Hồ Chí Minh cấp ngày 06/01/2010</p>
#                 </div>
#                 <div class="cpy-right-info-right">
#                     <a href="https://hotro.tiki.vn/hc/vi/articles/115005575826" target="_blank">
#                         <img src="https://salt.tikicdn.com/ts/upload/3d/6c/27/216e535ff06b1b925796957a017cbedb.png" height="36px" alt="">
#                     </a>
#                     <a href="http://online.gov.vn/HomePage/WebsiteDisplay.aspx?DocId=21201" target="_blank">
#                         <span class="tikicon icon-bo-cong-thuong"></span>
#                     </a>
#                 </div>
#             </div>
#         </div>
#         <div id="coupon-delivery"></div>
#             </footer>
#         <script>
#     var facebookAppId = 220558114759707;
#     // RECAPTCHA
#     var isNativeApp = false;
#     var rootUrl = 'https://tiki.vn';
#     var recaptchaKey = '6LcTOQUTAAAAAON_bNetEtgzm-yfBmCgLw17vxg_';
#     var renderRecaptcha = false;
#     var talalyticsStatus = 1;
#     var searchTuningVersion = "tuning.v1";
#
#
# </script>
#
#
#
#
#
#
# <script type="text/javascript">
# 	var recentlyViewed = 1;
# </script>
#
#
# <script type="text/javascript">
#
#     function recentlyViewTrack(productIds) {
#         var urlRecentlyviewTrack = "https://tiki.vn/add_recentlyviewed?ids="+productIds+"";
#         $('body').append('<img style="width:0px;height:0px;opacity:0;" src="'+urlRecentlyviewTrack+'">');
#     }
#
# </script>
#
#
#
#
#     <script src="https://salt.tikicdn.com/desktop/dist/vendor.js?v=nvms_200731092307"></script>    <script src="https://salt.tikicdn.com/desktop/dist/category.js?v=nvms_200731092307"></script>
# <!--  BEGIN TOKEN -->
# <input type="hidden" name="TIKI_CSRF_TOKEN" value="eHVHT2Q3NUJYSGZPZk41Y1hZY1lUZz09" />
# <!-- END TOKEN -->
#
#
#
#
# <script type="text/javascript">
#
#     </script>
#
#
#
#
#
# <!-- HANDLE MESSAGE FROM FACEBOOK LOGIN -->
# <script>
# 	var refFbLogin = "";
#
# 	window.addEventListener(
# 	  "message",
# 	  function (event) {
# 	    if(event.data === 'fb_reload_page') {
# 	    	window.location.reload();
# 	    }
# 	  }, false);
#
# </script>
# <!-- END HANDLE MESSAGE FROM FACEBOOK -->
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"5e70a0d5a3","applicationID":"469087689","transactionName":"YlcDYktZWxdTUkFcXFsdIkNKTFoJHVJUQVJZXQYZW0paE0FURxpaW1YETg==","queueTime":0,"applicationTime":186,"atts":"ThAAFANDSBk=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %% [markdown]
# ## Parse the Raw Text with BeautifulSoup
# In order to extract the information from the HTML file, we need to put it through a parser.
#
# A parser builds data structrure from input data (usually text), allowing us to easily find and extract the components of the data. __BeautifulSoup__ is one of the most popular HTML parser for Python.

# %%
from bs4 import BeautifulSoup

# r.text is a HTML file so we will use html.parser
soup = BeautifulSoup(r.text, 'html.parser')

# Make the soup object look nicer
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
#  <head>
#   <style>
#    html { background: #f4f4f4; } .async-hide body { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',1500,
#     {'GTM-53B3KKW':true});
#   </script>
#   <

# %% [markdown]
# ## Extract Information
# A __soup__ object has many method to find and extract information.
#
# - `<soup>.find(<tag>, {<attribute1>:<value1>, <attribute2>:<value2>})`: Return the FIRST occurence of `<tag>` with `<attributes>` equal to `<values>` in `<soup>` object. Output: Tag Object.
#
# - `<soup>.find_all(<tag>, {<attribute1>:<value1>, <attribute2>:<value2>})`: Return ALL occurences of `<tag>` with `<attributes>` equal to `<values>` in `<soup>` object. Output: ResultSet (List) containing one or many Tag Objects.
#
# - `<soup>.<tag>`: Return FIRST occurence of `<tag>` in `<soup>` object. Output: Tag Object.

# %%
# First occurence of the tag w/o attribute
first_p = soup.p
print("\nFirst occurence of the tag w/o attribute:")
# print("Type:",type(first_meta))
print(first_p)

# First occurence of the tag 
first_product = soup.find('div', {'class':'product-item'})
print("\nFirst occurence of the tag:")
# print("Type:",type(first_product))
print(first_product)


# All occurences of the tag
print("\nAll occurences of the tag:")
products = soup.find_all('div', {'class':'product-item'})
# print("Type:", type(articles))
# print(products)
# Out:
# First occurence of the tag w/o attribute:
# <p><a href="https://chrome.google.com/webstore/detail/tiki-assistant/ncpaceoemnbcjffjpjcgnbaklmkhdmak?hl=en-US&amp;gl=VN&amp;authuser=1" target="_blank">Tiki Assistant</a> là tiện ích chạy trực tiếp trên trình duyệt Chrome -  giúp gợi ý &amp; tìm kiếm nhanh các sản phẩm tốt nhất trên Tiki, phù hợp với nhu cầu tìm kiếm sản phẩm của bạn.</p>
#
# First occurence of the tag:
# <div class="product-item" data-brand="" data-category="Nhà Sách Tiki/English Books/Fiction - Literature/Romance" data-id="2048897" data-price="184800" data-score="" data-seller-product-id="2051203" data-title="Call Me By Your Name" product-sku="3381544740759" rel="">
# <a class="" data-id="2048897" href="/call-me-by-your-name-p2048897.html?spid=2051203&amp;src=category-page-8322&amp;2hi=0" title="Call Me By Your Name">
# <div class="content">
# <span class="image">
# <img alt="" class="product-image img-responsive" src="https://salt.tikicdn.com/cache/280x280/ts/product/ff/26/a2/fdf754ec5975dd1738775416e26feceb.jpg"/>
# <span class="product-right-icon">
# </span>
# </span>
# <p class="icons">
# </p>
# <p class="title">
#
#
#                                 Call Me By Your Name            </p>
# <p class="author">André Aciman</p>
# <p class="price-sale">
# <span class="final-price">
#                     184.800đ                                            <span class="sale-tag sale-tag-square">-30%</span>
# </span>
# <span class="price-regular">264.000đ</span>
# <span class="sale-tag sale-tag-square">-30%</span>
# </p>
# </div>
# <div class="price-tag-wrap">
# </div>
# <div class="review-wrap">
# <p class="rating">
# <span class="rating-content">
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# <span style="width:84%">
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# <i class="star"></i>
# </span>
# </span>
# </p>
# <p class="review">(39 nhận xét)</p>
# </div>
# <div class="ship-label-wrapper">
# </div>
# </a>
# </div>
#
# All occurences of the tag:

# %%
print(first_product.prettify())
print("title", first_product.find('p', {'class': 'title'}).text.strip())
print('img_url', first_product.img['src'])
print("url", first_product.find("a")['href'])
print("author", first_product.find("p", {'class': 'author'}).text)
print("price_sale", first_product.find("span", {'class': 'final-price'}).text.strip().split()[0][:-1].strip())
print("sale", first_product.find("span", {'class': 'sale-tag'}).text)
print("price_regular", first_product.find("span", {'class': 'price-regular'}).text[:-1])
print("rating", first_product.find("span", {'class': 'rating-content'}).span['style'].split(':')[-1][:-1])
print("reviewer", first_product.find("p", {'class': 'review'}).text.strip('(').split()[0])
# Out:
# <div class="product-item" data-brand="" data-category="Nhà Sách Tiki/English Books/Fiction - Literature/Romance" data-id="2048897" data-price="184800" data-score="" data-seller-product-id="2051203" data-title="Call Me By Your Name" product-sku="3381544740759" rel="">
#  <a class="" data-id="2048897" href="/call-me-by-your-name-p2048897.html?spid=2051203&amp;src=category-page-8322&amp;2hi=0" title="Call Me By Your Name">
#   <div class="content">
#    <span class="image">
#     <img alt="" class="product-image img-responsive" src="https://salt.tikicdn.com/cache/280x280/ts/product/ff/26/a2/fdf754ec5975dd1738775416e26feceb.jpg"/>
#     <span class="product-right-icon">
#     </span>
#    </span>
#    <p class="icons">
#    </p>
#    <p class="title">
#     Call Me By Your Name
#    </p>
#    <p class="author">
#     André Aciman
#    </p>
#    <p class="price-sale">
#     <span class="final-price">
#      184.800đ
#      <span class="sale-tag sale-tag-square">
#       -30%
#      </span>
#     </span>
#     <span class="price-regular">
#      264.000đ
#     </span>
#     <span class="sale-tag sale-tag-square">
#      -30%
#     </span>
#    </p>
#   </div>
#   <div class="price-tag-wrap">
#   </div>
#   <div class="review-wrap">
#    <p class="rating">
#     <span class="rating-content">
#      <i class="star">
#      </i>
#      <i class="star">
#      </i>
#      <i class="star">
#      </i>
#      <i class="star">
#      </i>
#      <i class="star">
#      </i>
#      <span style="width:84%">
#       <i class="star">
#       </i>
#       <i class="star">
#       </i>
#       <i class="star">
#       </i>
#       <i class="star">
#       </i>
#       <i class="star">
#       </i>
#      </span>
#     </span>
#    </p>
#    <p class="review">
#     (39 nhận xét)
#    </p>
#   </div>
#   <div class="ship-label-wrapper">
#   </div>
#  </a>
# </div>
#
# title Call Me By Your Name
# img_url https://salt.tikicdn.com/cache/280x280/ts/product/ff/26/a2/fdf754ec5975dd1738775416e26feceb.jpg
# url /call-me-by-your-name-p2048897.html?spid=2051203&src=category-page-8322&2hi=0
# author André Aciman
# price_sale 184.800
# sale -30%
# price_regular 264.000
# rating 84
# reviewer 39

# %% [markdown]
# With the Tag Object, we can also apply `.find()` and `.find_all()` method to search for its children tags.

# %%
# Find the p tag for article description
# <p class='description'> is a children tag of each article
description_tag = first_article.find('p', {'class':'description'})

print(description_tag.prettify())
# Out:
# <p class="description">
#  <a data-medium="Item-1" data-thumb="1" href="https://vnexpress.net/hon-21-000-nguoi-ha-noi-da-xet-nghiem-nhanh-ncov-4139226.html" title="Hơn 21.000 người Hà Nội đã xét nghiệm nhanh nCoV">
#   Trong 21.000 mẫu xét nghiệm nhanh, có hai trường hợp dương tính, tuy nhiên khi làm xét nghiệm khẳng định bằng phương pháp PCR đều có kết quả âm tính.
#  </a>
# </p>

# %% [markdown]
# Our data is contained inside the tags. Depending on which section of the tag contains the data, we will use a different method.

# %% [markdown]
# 1. __Data is the CONTENT of the tag__
#
# _E.g. The text that can be seen on the website_
#
# The content of the tag is the text between the starting tag and closing tag. To get this section, we use the attribute `.text`

# %%
# Extract the content of the tag
# The result is a string
description = description_tag.text
print(repr(description))
print(description)
print(type(description))

# The result is a string
# So we can apply string methods to it if it got any strange character
# description = description.replace('\xa0',' ')
# print(repr(description))

# %% [markdown]
# 2. __Data is the VALUE of an ATTRIBUTE of the tag.__
#
# _E.g. URLs, id, hidden information,..._
#
# Sometimes the information we need is the value of an attribute located inside the starting tag. To get this section, we index that attribute with square brackets `[ ]`, similar to a dictionary.

# %%
# Select the <a> tag inside description_tag
a_tag = description_tag.a 
print('Content:', a_tag)

# Extract the value of an attribute
title = a_tag['title']
print('Title:', repr(title))

# The result is also a string
print('Type:', type(title))
# Out:
# Content: <a data-medium="Item-1" data-thumb="1" href="https://vnexpress.net/hon-21-000-nguoi-ha-noi-da-xet-nghiem-nhanh-ncov-4139226.html" title="Hơn 21.000 người Hà Nội đã xét nghiệm nhanh nCoV">Trong 21.000 mẫu xét nghiệm nhanh, có hai trường hợp dương tính, tuy nhiên khi làm xét nghiệm khẳng định bằng phương pháp PCR đều có kết quả âm tính.</a>
# Title: 'Hơn 21.000 người Hà Nội đã xét nghiệm nhanh nCoV'
# Type: <class 'str'>

# %% [markdown]
# ## Putting it all together!
#
# Now that we learned how to find and extract information with BeautifulSoup. Let's write a program to solve the requirements!

# %% [markdown]
# ### Main Component of the Scraper

# %%
# We want to save information about all products in a list
data = []

# Find all products
products = soup.find_all('div', {'class':'product-item'})
# print(len(products))
# Extract information of each product
for product in products:
    
    # Each product is dictionary containing the required information
    d = {'title':'', 'author':'', 'price_sale': 0, 'sale': 0, 'price_regular': 0, 'rating': 0, 'reviewers': 0, 'img_url':'', 'url':''}

    # We use the try-except blocks to handle errors
    try:
        # use strip for all text to remove outer blank space
        
        #get title and strip the space outside of it
        try:
            d['title'] = product.find('p', {'class': 'title'}).text.strip()
        except:
            print('Wrong with title')
            print(product)
            
        try:
            d['img_url'] = product.img['src'].strip()
        except:
             print('Wrong with img_url')
             print(product)
            
        try:
            d['url'] = product.find("a")['href'].strip()
        except:
            print('Wrong with url')
            print(product)
            
        try:
            author = product.find('p', {'class': 'author'})
            if author:
                d['author'] = product.find('p', {'class': 'author'}).text.strip()
        except:
            print('Wrong with author')
            print(product)
            
        #get price sale, strip outside space, split to get first item and remove the 'd' at the end
        #remove '.' in price sale to convert to int or it will make casting error
        try:
            d['price_sale'] = int(product.find('span', {'class': 'final-price'}).text.strip().split()[0][:-1].strip().replace('.',''))
        except:
            print('Wrong with price_sale')
            print(product)
            
        try:
            
            sale = product.find('span', {'class': 'sale-tag'})
            if sale:
                d['sale'] = int(sale.text.strip(' -%'))
        except:
            print('Wrong with sale')
            #print(product.find('span', {'class': 'sale-tag'}).text.strip())
            print(product)
            
        try:
            price_regular = product.find('span', {'class': 'price-regular'})
            if price_regular:
                d['price_regular'] = int(price_regular.text.strip()[:-1].replace('.',''))
        except:
            print('Wrong with price_regular')
            print(product)
            
        # get the rating, split by ':' and get the last, remove '%' 
        try:
            
            rating = int(product.find('span', {'class': 'rating-content'}).span['style'].split(':')[-1][:-1].strip())
            # rating has 100% for 5 stars, 1 star is 20% so divide the rating for 20 
            d['rating'] = round((rating) / 20, 1)
        except:
            print('Wrong with rating')
            print(product)
            
        try:
            d['reviewers'] = int(product.find('p', {'class': 'review'}).text.strip('(').split()[0].strip())
        except:
            print('Wrong with reviewers')
            print(product)
        # Append the dictionary to data list
        data.append(d)
        
    except:
        # Skip if error and print error message
        print(product)
#         print("We got one product error!")

# %%
# here is the array of dictionary article objects we want
data
# Out:
# [{'title': 'Call Me By Your Name',
#   'author': 'André Aciman',
#   'price_sale': 184800,
#   'sale': 30,
#   'price_regular': 264000,
#   'rating': 4.2,
#   'reviewers': 39,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ff/26/a2/fdf754ec5975dd1738775416e26feceb.jpg',
#   'url': '/call-me-by-your-name-p2048897.html?spid=2051203&src=category-page-8322&2hi=0'},
#  {'title': "Oxford Advanced Learner's Dictionary 8th...",
#   'author': 'Oxford University Press',
#   'price_sale': 516700,
#   'sale': 13,
#   'price_regular': 595000,
#   'rating': 4.4,
#   'reviewers': 84,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/55/26/7c/3ad6cf393f130bda73bd9fa0bc3ce5a9.jpg',
#   'url': '/oxford-advanced-learner-s-dictionary-8th-edition-with-vietnamese-translation-and-cd-rom-paperback-p11119019.html?spid=11119020&src=category-page-8322&2hi=0'},
#  {'title': 'Vui Vẻ Không Quạu Nha - Tản Văn',
#   'author': 'Ở Đây Zui Nè',
#   'price_sale': 44850,
#   'sale': 35,
#   'price_regular': 69000,
#   'rating': 4.6,
#   'reviewers': 722,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/b2/56/d3/17262447faaef713be60d6b25ec0551d.jpg',
#   'url': '/vui-ve-khong-quau-nha-tan-van-p50751279.html?spid=50751280&src=category-page-8322&2hi=0'},
#  {'title': 'Muôn Kiếp Nhân Sinh (Many Lives - Many Times)',
#   'author': 'Nguyên Phong',
#   'price_sale': 109200,
#   'sale': 35,
#   'price_regular': 168000,
#   'rating': 4.8,
#   'reviewers': 725,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/30/ee/5a/dbf45bb1609085f9de51b44e0546dda4.jpg',
#   'url': '/muon-kiep-nhan-sinh-many-lives-many-times-p54748899.html?spid=54748900&src=category-page-8322&2hi=0'},
#  {'title': 'Đừng Lựa Chọn An Nhàn Khi Còn Trẻ',
#   'author': 'Cảnh Thiên',
#   'price_sale': 60750,
#   'sale': 25,
#   'price_regular': 81000,
#   'rating': 4.7,
#   'reviewers': 1597,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/eb/62/6b/0e56b45bddc01b57277484865818ab9b.jpg',
#   'url': '/dung-lua-chon-an-nhan-khi-con-tre-p11232442.html?spid=11232443&src=category-page-8322&2hi=0'},
#  {'title': 'Đắc Nhân Tâm (Khổ Lớn)',
#   'author': 'Dale Carnegie',
#   'price_sale': 49400,
#   'sale': 35,
#   'price_regular': 76000,
#   'rating': 4.6,
#   'reviewers': 2317,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/df/7d/da/cc713d2bcecd12ba82d5596ddbcac2d7.jpg',
#   'url': '/dac-nhan-tam-kho-lon-p480040.html?spid=192412&src=category-page-8322&2hi=0'},
#  {'title': 'Thám Tử Lừng Danh Conan Tập 97',
#   'author': 'Gosho Aoyama',
#   'price_sale': 20000,
#   'sale': 0,
#   'price_regular': 0,
#   'rating': 4.9,
#   'reviewers': 66,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/1c/38/86/9b6a579e095939a7c9365752ecac72b4.jpg',
#   'url': '/tham-tu-lung-danh-conan-tap-97-p58340699.html?spid=58340700&src=category-page-8322&2hi=0'},
#  {'title': '999 Lá Thư Gửi Cho Chính Mình – Mong Bạn Trở...',
#   'author': 'Miêu Công Tử',
#   'price_sale': 74250,
#   'sale': 25,
#   'price_regular': 99000,
#   'rating': 4.6,
#   'reviewers': 890,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/c4/46/99/0dcc6e04aca0a78cda09a2d8b156dccb.jpg',
#   'url': '/999-la-thu-gui-cho-chinh-minh-mong-ban-tro-thanh-phien-ban-hoan-hao-nhat-p5143339.html?spid=5143341&src=category-page-8322&2hi=0'},
#  {'title': 'Nóng Giận Là Bản Năng , Tĩnh Lặng Là Bản Lĩnh',
#   'author': 'Tống Mặc',
#   'price_sale': 71200,
#   'sale': 20,
#   'price_regular': 89000,
#   'rating': 4.7,
#   'reviewers': 774,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/70/9a/98/e6d54019a2079b9565114bce93b245b7.jpg',
#   'url': '/nong-gian-la-ban-nang-tinh-lang-la-ban-linh-p26114399.html?spid=26114400&src=category-page-8322&2hi=0'},
#  {'title': 'Sapiens: Lược Sử Loài Người (Tái Bản Có...',
#   'author': 'Yuval Noah Harari',
#   'price_sale': 133586,
#   'sale': 36,
#   'price_regular': 209000,
#   'rating': 4.7,
#   'reviewers': 931,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/56/3f/4f/f4e6621e69775643d22604bccef281bf.jpg',
#   'url': '/sapiens-luoc-su-loai-nguoi-tai-ban-co-chinh-sua-p888553.html?spid=888555&src=category-page-8322&2hi=0'},
#  {'title': 'COMBO SÁCH: KHƠI DẬY CẢM HỨNG HỌC TẬP + BÍ...',
#   'author': 'Lê Văn Thành',
#   'price_sale': 345000,
#   'sale': 22,
#   'price_regular': 440000,
#   'rating': 4.5,
#   'reviewers': 68,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/13/ee/e8/4cc5ff276ae7540e5fe3d3b35b9f7cec.jpg',
#   'url': '/combo-khoi-day-cam-hung-hoc-tap-bi-kip-hoc-tap-toan-dien-p34271371.html?spid=34271372&src=category-page-8322&2hi=0'},
#  {'title': 'Vẫn Là Mùa Hạ Nhưng Không Còn Chúng Ta (Tản...',
#   'author': 'Hiên',
#   'price_sale': 66400,
#   'sale': 20,
#   'price_regular': 83000,
#   'rating': 4.7,
#   'reviewers': 42,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/91/db/dd/3d162af4b91b358b5dfaf8eae274b2be.jpg',
#   'url': '/van-la-mua-ha-nhung-khong-con-chung-ta-tan-van-p57669095.html?spid=58032659&src=category-page-8322&2hi=0'},
#  {'title': 'Sách Muôn Kiếp Nhân Sinh Tặng Bookmark',
#   'author': '',
#   'price_sale': 132000,
#   'sale': 21,
#   'price_regular': 168000,
#   'rating': 4.8,
#   'reviewers': 99,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/aa/ce/e5/38cde4cbfa65e85905301a1f759d5e4d.jpg',
#   'url': '/sach-muon-kiep-nhan-sinh-tang-bookmark-p54683089.html?spid=56941182&src=category-page-8322&2hi=0'},
#  {'title': 'Cân Bằng Cảm Xúc, Cả Lúc Bão Giông',
#   'author': 'Richard Nicholls',
#   'price_sale': 76800,
#   'sale': 20,
#   'price_regular': 96000,
#   'rating': 4.5,
#   'reviewers': 745,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/fd/61/1d/a19424cfe9d113c32732d93cf2d5f59a.jpg',
#   'url': '/can-bang-cam-xuc-ca-luc-bao-giong-p14462349.html?spid=14462350&src=category-page-8322&2hi=0'},
#  {'title': 'Nhà Giả Kim',
#   'author': 'Paulo Coelho',
#   'price_sale': 51689,
#   'sale': 25,
#   'price_regular': 69000,
#   'rating': 4.7,
#   'reviewers': 4428,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/66/5f/5a/312bac222584d52fea5e9d644369b254.jpg',
#   'url': '/nha-gia-kim-p378448.html?spid=77142&src=category-page-8322&2hi=0'},
#  {'title': 'Chủ Nghĩa Khắc Kỷ - Phong Cách Sống Bản Lĩnh...',
#   'author': 'William B. Irvine',
#   'price_sale': 81250,
#   'sale': 35,
#   'price_regular': 125000,
#   'rating': 4.6,
#   'reviewers': 285,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/97/61/91/a9b293f184d4dbbc2afc416b539f2bca.jpg',
#   'url': '/chu-nghia-khac-ky-phong-cach-song-ban-linh-va-binh-than-p49459956.html?spid=49459957&src=category-page-8322&2hi=0'},
#  {'title': 'Đàn Ông Sao Hỏa Đàn Bà Sao Kim',
#   'author': 'John Gray',
#   'price_sale': 131600,
#   'sale': 30,
#   'price_regular': 188000,
#   'rating': 4.5,
#   'reviewers': 524,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/0a/f6/38/bc10734989977da424642a1c4750eee2.jpg',
#   'url': '/dan-ong-sao-hoa-dan-ba-sao-kim-p10005245.html?spid=10005246&src=category-page-8322&2hi=0'},
#  {'title': 'Tôi Quyết Định Sống Cho Chính Tôi (Tặng Kèm...',
#   'author': 'Kim Suhyun',
#   'price_sale': 65269,
#   'sale': 26,
#   'price_regular': 88000,
#   'rating': 4.8,
#   'reviewers': 700,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/c1/6a/3e/537f7b9bb219be81e217e0c7b5b037e6.jpg',
#   'url': '/toi-quyet-dinh-song-cho-chinh-toi-tang-kem-1-so-to-do-list-2020-p46107062.html?spid=46107064&src=category-page-8322&2hi=0'},
#  {'title': 'Sức Mạnh Của Ngôn Từ\xa0(Tặng Kèm 1 Photocard...',
#   'author': 'Yun Naru',
#   'price_sale': 76800,
#   'sale': 20,
#   'price_regular': 96000,
#   'rating': 4.9,
#   'reviewers': 99,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/54/6d/2f/b4be918982e5df06cc057454e806651e.jpg',
#   'url': '/suc-manh-cua-ngon-tu-tang-kem-1-photocard-mintbooks-limited-p57870426.html?spid=57870427&src=category-page-8322&2hi=0'},
#  {'title': 'Tôi Từng Nghĩ Mọi Thứ Sẽ Ổn Khi Trở Thành...',
#   'author': 'Kim Haenam',
#   'price_sale': 76800,
#   'sale': 20,
#   'price_regular': 96000,
#   'rating': 4.6,
#   'reviewers': 80,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/0b/e4/9d/9819a2afb854e301ebaf93e8e4a8a9d3.jpg',
#   'url': '/toi-tung-nghi-moi-thu-se-on-khi-tro-thanh-nguoi-lon-tang-kem-1-bookmark-p56692532.html?spid=56692533&src=category-page-8322&2hi=0'},
#  {'title': 'Máy Tính Khoa Học Casio FX-580VN X',
#   'author': '',
#   'price_sale': 575000,
#   'sale': 12,
#   'price_regular': 650000,
#   'rating': 4.7,
#   'reviewers': 1231,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/88/06/8f/79165cb73b33931e9716152dab932640.jpg',
#   'url': '/may-tinh-khoa-hoc-casio-fx-580vn-x-p3014291.html?spid=3014293&src=category-page-8322&2hi=0'},
#  {'title': 'Kiên Trì Ắt Được Đền Đáp (Tái Bản 2020)',
#   'author': 'Nhiều Tác Giả',
#   'price_sale': 42000,
#   'sale': 35,
#   'price_regular': 65000,
#   'rating': 4.7,
#   'reviewers': 84,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/a0/73/4f/92af6309562efb8d90602ab2efdf42b3.jpg',
#   'url': '/kien-tri-at-duoc-den-dap-tai-ban-2020-p54614795.html?spid=54614796&src=category-page-8322&2hi=0'},
#  {'title': 'Nhà Lãnh Đạo Không Chức Danh',
#   'author': 'Robin Sharma',
#   'price_sale': 53600,
#   'sale': 33,
#   'price_regular': 80000,
#   'rating': 4.7,
#   'reviewers': 332,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/media/catalog/product/n/h/nhalanhdao.u2769.d20170307.t090846.484463.jpg',
#   'url': '/nha-lanh-dao-khong-chuc-danh-p579823.html?spid=20491965&src=category-page-8322&2hi=0'},
#  {'title': 'Hành Trình Về Phương Đông (Tái Bản 2019)',
#   'author': 'Nguyên Phong',
#   'price_sale': 57200,
#   'sale': 35,
#   'price_regular': 88000,
#   'rating': 4.8,
#   'reviewers': 382,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/46/9d/88/6560a409f40c37ac63d4e279bbea34b7.jpg',
#   'url': '/hanh-trinh-ve-phuong-dong-tai-ban-2019-p15415622.html?spid=15415623&src=category-page-8322&2hi=0'},
#  {'title': 'Tôi Tài Giỏi - Bạn Cũng Thế (Tái Bản 2019 )',
#   'author': 'Adam Khoo',
#   'price_sale': 90000,
#   'sale': 24,
#   'price_regular': 118000,
#   'rating': 4.8,
#   'reviewers': 430,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/8c/c5/bd/e7b36f74cc3c42c1fef5b6770e0e6d83.jpg',
#   'url': '/toi-tai-gioi-ban-cung-the-tai-ban-2019-p10694712.html?spid=10694713&src=category-page-8322&2hi=0'},
#  {'title': 'Dạy Con Làm Giàu (Tập 1) - Để Không Có Tiền...',
#   'author': 'Robert T. Kiyosaki',
#   'price_sale': 43550,
#   'sale': 33,
#   'price_regular': 65000,
#   'rating': 4.7,
#   'reviewers': 304,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/17/02/d1/52dde080f00d414a2d441c544c76d9c9.jpg',
#   'url': '/day-con-lam-giau-tap-1-de-khong-co-tien-van-tao-ra-tien-cha-giau-cha-ngheo-tai-ban-p7833728.html?spid=20483119&src=category-page-8322&2hi=0'},
#  {'title': 'Combo 999 Lá Thư Gửi Cho Chính Mình - Tặng...',
#   'author': 'Miêu Công Tử',
#   'price_sale': 198000,
#   'sale': 0,
#   'price_regular': 0,
#   'rating': 4.8,
#   'reviewers': 468,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/2e/c6/a6/38911c9a01343bcd1d3b7f9399f3275d.jpg',
#   'url': '/combo-999-la-thu-gui-cho-chinh-minh-tang-kem-bookmark-tron-bo-2-tap-p11081535.html?spid=11785026&src=category-page-8322&2hi=0'},
#  {'title': 'Công Phá Toán 3',
#   'author': 'Ngọc Huyền LB',
#   'price_sale': 175000,
#   'sale': 7,
#   'price_regular': 189000,
#   'rating': 4.9,
#   'reviewers': 1431,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/1d/b3/2c/580c845d55ef624950270b8ad380a132.jpg',
#   'url': '/cong-pha-toan-3-p970950.html?spid=13306544&src=category-page-8322&2hi=0'},
#  {'title': 'Đừng Bao Giờ Đi Ăn Một Mình (Tái Bản)',
#   'author': 'Keith Ferrazzi',
#   'price_sale': 74890,
#   'sale': 33,
#   'price_regular': 112000,
#   'rating': 4.7,
#   'reviewers': 386,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/8e/c5/c3/9f680d49c05be61065c81a6e6fce4faa.jpg',
#   'url': '/dung-bao-gio-di-an-mot-minh-tai-ban-p985266.html?spid=985318&src=category-page-8322&2hi=0'},
#  {'title': 'Đời Ngắn Đừng Ngủ Dài (Tái Bản)',
#   'author': 'Robin Sharma',
#   'price_sale': 50250,
#   'sale': 33,
#   'price_regular': 75000,
#   'rating': 4.6,
#   'reviewers': 443,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/57/44/86/19de0644beef19b9b885d0942f7d6f25.jpg',
#   'url': '/doi-ngan-dung-ngu-dai-tai-ban-p8835159.html?spid=8835160&src=category-page-8322&2hi=0'},
#  {'title': 'Thiết Kế Cuộc Đời Thịnh Vượng - Design a...',
#   'author': 'Thái Phạm',
#   'price_sale': 199000,
#   'sale': 0,
#   'price_regular': 0,
#   'rating': 4.9,
#   'reviewers': 592,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/cf/48/6b/1d51a7167d97daad0370b76db21b4055.jpg',
#   'url': '/thiet-ke-cuoc-doi-thinh-vuong-design-a-prosperous-life-p49249526.html?spid=49249529&src=category-page-8322&2hi=0'},
#  {'title': 'Combo Cà Phê Cùng Tony và Trên Đường Băng',
#   'author': '',
#   'price_sale': 105300,
#   'sale': 38,
#   'price_regular': 170000,
#   'rating': 4.8,
#   'reviewers': 548,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/8e/7a/61/47f4dfb634e076ff7c5418580ea8578c.jpg',
#   'url': '/combo-ca-phe-cung-tony-va-tren-duong-bang-p5852521.html?spid=9365728&src=category-page-8322&2hi=0'},
#  {'title': 'Dám Bị Ghét',
#   'author': 'Koga Fumitake',
#   'price_sale': 62400,
#   'sale': 35,
#   'price_regular': 96000,
#   'rating': 4.6,
#   'reviewers': 613,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/74/11/ff/6304c47fec56e6f0b2110be65af0c7c2.jpg',
#   'url': '/dam-bi-ghet-p1476937.html?spid=1476939&src=category-page-8322&2hi=0'},
#  {'title': 'Hộp bút đa zi năng 5 in 1',
#   'author': '',
#   'price_sale': 195000,
#   'sale': 44,
#   'price_regular': 350000,
#   'rating': 4.3,
#   'reviewers': 84,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/d6/7a/81/3a294c1335f17c5b13618c06a770184f.jpg',
#   'url': '/hop-but-da-zi-nang-5-in-1-p22782784.html?spid=55962848&src=category-page-8322&2hi=0'},
#  {'title': 'Bạn Đắt Giá Bao Nhiêu?',
#   'author': 'Vãn Tình',
#   'price_sale': 74250,
#   'sale': 25,
#   'price_regular': 99000,
#   'rating': 4.7,
#   'reviewers': 1535,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/87/c9/c0/bfebf4adcb31c8eb5c39fd3779cc4b68.jpg',
#   'url': '/ban-dat-gia-bao-nhieu-p1694077.html?spid=1694079&src=category-page-8322&2hi=0'},
#  {'title': 'Tôi Tự Học',
#   'author': 'Thu Giang - Nguyễn Duy Cần',
#   'price_sale': 40200,
#   'sale': 33,
#   'price_regular': 60000,
#   'rating': 4.5,
#   'reviewers': 344,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/media/catalog/product/n/x/nxbtre_full_28032017_020337.u5102.d20170331.t150309.516945.jpg',
#   'url': '/toi-tu-hoc-p599055.html?spid=599061&src=category-page-8322&2hi=0'},
#  {'title': '25 Chuyên Đề Ngữ Pháp Tiếng Anh Trọng Tâm –...',
#   'author': '',
#   'price_sale': 59400,
#   'sale': 46,
#   'price_regular': 110000,
#   'rating': 4.7,
#   'reviewers': 216,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/d3/ee/73/18dca42a5cf75f6b8a603caf80bbf9c9.jpg',
#   'url': '/25-chuyen-de-ngu-phap-tieng-anh-trong-tam-tap-1-p4040663.html?spid=4040665&src=category-page-8322&2hi=0'},
#  {'title': 'Tuổi Trẻ Đáng Giá Bao Nhiêu (Tái Bản)',
#   'author': 'Rosie Nguyễn',
#   'price_sale': 59889,
#   'sale': 25,
#   'price_regular': 80000,
#   'rating': 4.6,
#   'reviewers': 610,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/f8/34/c8/5fbf2a6f9d07b76d98e2fff2b29b0d3c.jpg',
#   'url': '/tuoi-tre-dang-gia-bao-nhieu-tai-ban-p7718733.html?spid=7718734&src=category-page-8322&2hi=0'},
#  {'title': 'Cẩm Nang Cấu Trúc Tiếng Anh',
#   'author': 'Trang Anh',
#   'price_sale': 74878,
#   'sale': 24,
#   'price_regular': 98000,
#   'rating': 4.8,
#   'reviewers': 313,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/b2/c7/b2/617e1165b21f498aea14cfd110bd5f10.jpg',
#   'url': '/cam-nang-cau-truc-tieng-anh-p20444622.html?spid=29878198&src=category-page-8322&2hi=0'},
#  {'title': 'Từ Tốt Đến Vĩ Đại',
#   'author': 'Jim Collins',
#   'price_sale': 76890,
#   'sale': 33,
#   'price_regular': 115000,
#   'rating': 4.3,
#   'reviewers': 251,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/media/catalog/product/n/x/nxbtre_full_06372017_103735.u547.d20170117.t105220.139884.jpg',
#   'url': '/tu-tot-den-vi-dai-p572433.html?spid=308347&src=category-page-8322&2hi=0'},
#  {'title': 'Tui Ship Đối Thủ X Tui',
#   'author': 'PEPA',
#   'price_sale': 119250,
#   'sale': 25,
#   'price_regular': 159000,
#   'rating': 5.0,
#   'reviewers': 75,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/8d/13/b2/bac8e69ddcbf58144aba32576492e9ce.jpg',
#   'url': '/tui-ship-doi-thu-x-tui-p57587819.html?spid=57587820&src=category-page-8322&2hi=0'},
#  {'title': 'Làm Bạn Với Bầu Trời (Bìa Mềm) (Tặng Kèm...',
#   'author': 'Nguyễn Nhật Ánh',
#   'price_sale': 60400,
#   'sale': 45,
#   'price_regular': 110000,
#   'rating': 4.9,
#   'reviewers': 608,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/af/a1/4b/92477ec9b6688060b2b5d2022a60d3e6.jpg',
#   'url': '/lam-ban-voi-bau-troi-bia-mem-tang-kem-khung-anh-so-luong-co-han-p31509726.html?spid=31509727&src=category-page-8322&2hi=0'},
#  {'title': 'Power Vs Force - Trường Năng Lượng Và Những...',
#   'author': 'David R.Hawkins',
#   'price_sale': 110789,
#   'sale': 29,
#   'price_regular': 155000,
#   'rating': 4.6,
#   'reviewers': 39,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/99/91/33/5e3634829f1bf05e16aef5cd1b1f3479.jpg',
#   'url': '/power-vs-force-truong-nang-luong-va-nhung-nhan-to-quyet-dinh-tinh-than-va-suc-khoe-con-nguoi-p56307244.html?spid=57009633&src=category-page-8322&2hi=0'},
#  {'title': 'Tony Buổi Sáng - Trên Đường Băng (Tái Bản...',
#   'author': '',
#   'price_sale': 52000,
#   'sale': 35,
#   'price_regular': 80000,
#   'rating': 4.8,
#   'reviewers': 1069,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/61/87/8a/082a07cec3232115e2b22636fd71593c.jpg',
#   'url': '/tony-buoi-sang-tren-duong-bang-tai-ban-2017-p1005148.html?spid=20476560&src=category-page-8322&2hi=0'},
#  {'title': 'Sống Thực Tế Giữa Đời Thực Dụng',
#   'author': 'Mễ Mông',
#   'price_sale': 63700,
#   'sale': 35,
#   'price_regular': 98000,
#   'rating': 4.7,
#   'reviewers': 1284,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/25/d6/2c/f88080bba78a779fb78e1b76b73a9813.jpg',
#   'url': '/song-thuc-te-giua-doi-thuc-dung-p6201209.html?spid=6201211&src=category-page-8322&2hi=0'},
#  {'title': 'Giấy vẽ Màu Nước Nabii Aqua Fat 300gsm',
#   'author': '',
#   'price_sale': 90000,
#   'sale': 0,
#   'price_regular': 0,
#   'rating': 4.8,
#   'reviewers': 273,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/33/56/6f/186d2e281635ba2b43352be947ccf48a.jpg',
#   'url': '/giay-ve-mau-nuoc-nabii-aqua-fat-300gsm-p22984216.html?spid=22984218&src=category-page-8322&2hi=0'},
#  {'title': 'Nuôi Con Không Phải Là Cuộc Chiến 2 (Trọn Bộ...',
#   'author': 'Hachun Lyonnet (Hà Chũn)',
#   'price_sale': 193336,
#   'sale': 39,
#   'price_regular': 319000,
#   'rating': 4.8,
#   'reviewers': 443,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/32/3d/a5/69a6c74574f882fec47557ddb90a2e65.jpg',
#   'url': '/nuoi-con-khong-phai-la-cuoc-chien-2-tron-bo-3-tap-p3953475.html?spid=3953573&src=category-page-8322&2hi=0'},
#  {'title': 'Những Gì Đã Qua Đừng Nghĩ Lại Quá Nhiều (Tái...',
#   'author': 'Minh Mẫn',
#   'price_sale': 46800,
#   'sale': 35,
#   'price_regular': 72000,
#   'rating': 4.5,
#   'reviewers': 208,
#   'img_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ce/6b/d1/5eedba8141133ef2a09600bc2682fc34.jpg',
#   'url': '/nhung-gi-da-qua-dung-nghi-lai-qua-nhieu-tai-ban-2020-tang-kem-01-bookmark-p50246184.html?spid=50246185&src=category-page-8322&2hi=0'}]

# %% [markdown]
# ### Package into Functions

# %% [markdown]
# As a good developer, we always need to

# %%
# Import Library
import requests
from bs4 import BeautifulSoup

def get_url(url):
    """Get parsed HTML from url
      Input: url to the webpage
      Output: Parsed HTML text of the webpage
    """
    # Send GET request
    r = requests.get(url)

    # Parse HTML text
    soup = BeautifulSoup(r.text, 'html.parser')

    return soup

def scrape_vnexpress(url="https://vnexpress.net/"):
    """Scrape the home page of vnexpress
      Input: url to the webpage. Default: https://vnexpress.net/
      Output: A list containing scraped data of all articles
    """

    # Get parsed HTML
    soup = get_url(url)


    # Find all article tags
    articles = soup.find_all('article', {'class':'item-news'})

    # List containing data of all articles
    data = []

    # Extract information of each article
    for article in articles:

        d = {'title':'', 'url':'', 'image_url':'', 'description':''}
        
        try:
          d['title'] = article.a['title']
          d['url'] = article.a['href']
          # It is fine to clean the data inside the scraper
          # But it is more recommended to do it afterwards
          d['description'] = article.p.text.replace('\xa0','').strip('\n')
          if article.img:
            d['image_url'] = article.img['data-src']  # or should we use ['src'] ?

          # Append the dictionary to data list
          data.append(d)
        except:
          # Skip if error and print error message
          print("We got one article error!")

    return data

# %% [markdown]
# ### Test the Scraper

# %%
# Test the scraper
data = scrape_vnexpress()
data

# %% [markdown]
# ###Convert your result to pandas dataframe

# %%
# Save data to a DataFrame
import pandas as pd

articles = pd.DataFrame(data = data, columns = data[0].keys())

# %%
type(articles)

# %% [markdown]
# ##Store your result

# %% [markdown]
# ###Option 1: Store your pandas dataframe to pickle file and load them again

# %%
articles.to_pickle("./result.pkl")

# %%
unpickled_result = pd.read_pickle("./result.pkl")

# %%
unpickled_result

# %% [markdown]
# ###Option 2: Store your pandas dataframe to csv file

# %%
# it should store a "result.csv" in your current folder, you can download it to store it
articles.to_csv("./result.csv", index=False)
